# %%
# !pip install nasdaq-data-link

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
import nasdaqdatalink

# %%
# pipeline end to end pa vidjeti sto se tocno mijenja...

# %%
# Gathering the data for Natural Gas

data_naturalgas = nasdaqdatalink.get("EIA/NG_RNGC1_D", start_date="2000-01-01", end_date="2022-03-08")

# %%
# Now we need to see if the data is formated in the way we want,
# meaning we have to have just dates and prices

data_naturalgas.head()
# Out:
#             Value
# Date
# 2000-01-04  2.176
# 2000-01-05  2.168
# 2000-01-06  2.196
# 2000-01-07  2.173
# 2000-01-10  2.216

# %%
# To double check the data we can plot it, but also we need to plot the data
# in order to conduct our exploratory analysis

plt.ylabel("Natural Gas Price - Fututres Contracts")

data_naturalgas.Value.plot(figsize=(10,5))

# %%
# Gathering the data for Oil

data_oil = nasdaqdatalink.get("OPEC/ORB", start_date="2000-01-01", end_date="2022-03-08")

# %%
data_oil.head()
# Out:
#             Value
# Date
# 2003-01-02  30.05
# 2003-01-03  30.83
# 2003-01-06  30.71
# 2003-01-07  29.72
# 2003-01-08  28.86

# %%
plt.ylabel("Oil Price - OPEC Crude Oil")

data_oil.Value.plot(figsize=(10,5))

# %%
# Gathering the data for Natural Gas and Oil consumption in Europe

data_oil_consumption = nasdaqdatalink.get("BP/OIL_CONSUM_D_EUR", start_date="2000-01-01", end_date="2020-12-31")
data_naturalgas_consumption = nasdaqdatalink.get("BP/GAS_CONSUM_D_EUR", start_date="2000-01-01", end_date="2020-12-31")

# %%
data_oil_consumption.head()
# Out:
#                    Value
# Date
# 2000-12-31  16185.345815
# 2001-12-31  16440.743989
# 2002-12-31  16395.612397
# 2003-12-31  16476.058791
# 2004-12-31  16589.038582

# %%
data_naturalgas_consumption.head()
# Out:
#                 Value
# Date
# 2000-12-31  53.888015
# 2001-12-31  55.096599
# 2002-12-31  55.271956
# 2003-12-31  57.771286
# 2004-12-31  59.008927

# %%
plt.ylabel("Oil Consumption - Total Europe Daily Average")

data_oil_consumption.Value.plot(figsize=(10,5))

# %%
plt.ylabel("Natural Gas Consumption - Total Europe Daily Average")

data_naturalgas_consumption.Value.plot(figsize=(10,5))
